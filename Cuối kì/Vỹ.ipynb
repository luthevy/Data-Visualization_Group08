# %%
# Importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#        Unnamed: 0        Date Country              City       Specie  count  \
# 0               0  17/07/2020      VN  Ho Chi Minh City  temperature     24
# 1               1  21/10/2020      VN  Ho Chi Minh City  temperature     24
# 2               2  07/11/2020      VN  Ho Chi Minh City  temperature     24
# 3               3  22/11/2020      VN  Ho Chi Minh City  temperature     24
# 4               4  10/01/2020      VN  Ho Chi Minh City  temperature     24
# ...           ...         ...     ...               ...          ...    ...
# 16203       16222  26/02/2020      VN           Ha Long           co     28
# 16204       16223  27/02/2020      VN           Ha Long           co     34
# 16205       16224  29/02/2020      VN           Ha Long           co     22
# 16206       16225  24/06/2020      VN           Ha Long           co     48
# 16207       16226  25/06/2020      VN           Ha Long           co     48
#
#         min   max  median  variance
# ...

# %% [markdown]
# ## Histogram thể hiện phân bố dữ liệu của các thành phố nơi được thu thập

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(7, 7))
sns.histplot(x = df["City"], color='skyblue',kde = False)
ax.patches[2].set_facecolor('salmon')

# %% [markdown]
# ## Histogram thể hiện phân bố dữ liệu của thành phần môi trường được thu thập

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(15, 8))
sns.histplot(x = df["Specie"], color='skyblue',kde = False)
ax.patches[4].set_facecolor('salmon')

# %% [markdown]
# ## Timeline chart thể hiện sự thay đổi giá trị cực đại của chỉ số bụi mịn pm25 ở TPHCM

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

# %%
new_df = df[df['City']=='Ho Chi Minh City'] 
new_df = df[df['Specie']=='pm25']

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = new_df['Date'], y = new_df['max'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='max'>

# %% [markdown]
# ## Boxplot thể hiện phân bố giá trị của chỉ số nhiệt độ ở TPHCM

# %%
new_df = df.drop(labels=['Date','Country','City','Unnamed: 0','Specie','count','variance','median'], axis=1)

# %%
df = pd.DataFrame(data = new_df, columns = list(new_df.columns))
plt.figure(figsize = (8,8))
sns.boxplot(x="variable", y="value", data=pd.melt(df))
plt.xlabel("Temperature")
plt.ylabel("Values")
plt.show()
